# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;">
# 1) Draw a bicolour features interaction diagram between the columns with the numbers of the last and second to last digits of your SID,
# where: </h3> </html>

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;">
# In case these numbers are the same, then take the next number in order as another column number. For example, if your SID is 2287477, then you plot the bicolour diagram of the 7th and 8th columns. If your SID is 2287499, then the 9th and 0.
#
# 2) Add the code and result to your Lab Logbook.
# </h3> </html>

# %% [markdown]
# 2362238 | 3 8

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('telecom_churn.csv')
data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')
sns.countplot(x=data['International plan'], palette = "Set3");

# %%
fig = plt.figure(figsize=(11,7))

plt.scatter(data['International plan'], data['Total day charge'], color = Clr);
plt.xlabel('International plan');
plt.ylabel('Total day charge');

# %%
fig = plt.figure(figsize=(11,7))

plt.scatter(data['International plan'], data['Total day charge'], color = Clr, s=(data['Total intl charge'] + 0.05) );
plt.xlabel('International plan');
plt.ylabel('Total day charge');

# %%
sns.boxplot(x = 'International plan', y = 'Total day charge', data=data, palette = "Set1");

# %%
fig = plt.figure(figsize=(13, 5))
sns.boxplot(x = 'International plan', y = 'Total day charge', data=data, palette = "Set2");
